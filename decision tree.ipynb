# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv(r"C:\Users\nirma\Downloads\winequality-red.csv")

# %%
print(df.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import  train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25, random_state= 42)

# %%
print('There are {} samples in the training set and {} samples in the test set'.format(
x_train.shape[0], x_test.shape[0]))
print()
# Out:
# There are 1199 samples in the training set and 400 samples in the test set

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
sc.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scaled = sc.transform(x_train)
x_test_scaled = sc.transform(x_test)

# %%
dtree = DecisionTreeClassifier(criterion='gini', random_state =0)

# %%
dtree.fit(x_train_scaled,y_train)
y_pred = dtree.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
from sklearn.metrics import classification_report

# %%
y_pred = dtree.fit(x_train_scaled,y_train)
dtree.predict(x_test_scaled)
# Out:
# array([5, 4, 5, 5, 6, 5, 5, 5, 8, 6, 7, 5, 5, 5, 6, 6, 5, 5, 7, 5, 5, 6,
#        5, 6, 6, 6, 6, 5, 5, 6, 5, 6, 6, 5, 5, 5, 6, 6, 6, 7, 5, 5, 6, 5,
#        7, 5, 7, 6, 5, 5, 5, 5, 5, 6, 5, 6, 6, 6, 7, 5, 5, 8, 6, 5, 7, 4,
#        6, 6, 6, 5, 6, 6, 6, 6, 6, 5, 7, 5, 6, 7, 5, 7, 5, 6, 7, 7, 5, 6,
#        7, 5, 7, 7, 4, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 7, 6, 7, 6, 5, 7, 3,
#        7, 5, 7, 5, 5, 7, 6, 6, 5, 5, 7, 6, 6, 6, 7, 5, 7, 5, 5, 6, 6, 5,
#        5, 6, 5, 6, 5, 6, 6, 6, 7, 6, 5, 5, 7, 5, 5, 6, 5, 5, 6, 6, 6, 5,
#        6, 5, 7, 7, 5, 6, 7, 6, 7, 5, 5, 5, 6, 5, 5, 5, 5, 4, 7, 6, 7, 7,
#        6, 5, 5, 5, 4, 6, 7, 8, 5, 6, 6, 6, 6, 6, 6, 7, 5, 7, 5, 5, 5, 6,
#        6, 7, 5, 6, 5, 5, 7, 5, 5, 4, 6, 5, 8, 5, 5, 7, 6, 4, 6, 5, 5, 6,
#        6, 6, 6, 6, 6, 5, 5, 7, 5, 5, 7, 4, 6, 6, 5, 7, 5, 7, 6, 5, 5, 6,
#        5, 7, 5, 7, 6, 5, 6, 5, 6, 5, 6, 5, 6, 5, 5, 4, 6, 7, 8, 6, 5, 6,
#        5, 5, 5, 5, 6, 6, 5, 7, 5, 6, 6, 6, 5, 8, 6, 6, 6, 5, 6, 6, 6, 7,
# ...

# %%
y_pred = dtree.predict(x_test_scaled)

# %%
from sklearn.model_selection import KFold

# %%
scores = KFold(n_splits=10, shuffle = False, random_state = None)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
acc = accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.58

# %%
CR = classification_report(y_test,y_pred)
print(CR)
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.08      0.08      0.08        13
#            5       0.69      0.65      0.67       164
#            6       0.63      0.57      0.60       169
#            7       0.40      0.56      0.47        48
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.58       400
#    macro avg       0.30      0.31      0.30       400
# weighted avg       0.60      0.58      0.59       400

# %%
CM = confusion_matrix(y_test,y_pred)
print(CR)
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.08      0.08      0.08        13
#            5       0.69      0.65      0.67       164
#            6       0.63      0.57      0.60       169
#            7       0.40      0.56      0.47        48
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.58       400
#    macro avg       0.30      0.31      0.30       400
# weighted avg       0.60      0.58      0.59       400

# %%
f"the model is showing the accuracy_score of DecisionTreeClassification is :{acc}, and classification_report is :{CR}, and confusionmatrix is :{CM}"
# Out:
# 'the model is showing the accuracy_score of DecisionTreeClassification is :0.58, and classification_report is :              precision    recall  f1-score   support\n\n           3       0.00      0.00      0.00         1\n           4       0.08      0.08      0.08        13\n           5       0.69      0.65      0.67       164\n           6       0.63      0.57      0.60       169\n           7       0.40      0.56      0.47        48\n           8       0.00      0.00      0.00         5\n\n    accuracy                           0.58       400\n   macro avg       0.30      0.31      0.30       400\nweighted avg       0.60      0.58      0.59       400\n, and confusionmatrix is :[[  0   0   1   0   0   0]\n [  0   1   4   7   1   0]\n [  2   8 107  37   9   1]\n [  0   2  39  97  28   3]\n [  0   1   4  12  27   4]\n [  0   0   1   1   3   0]]'
